# %% [markdown]
# #### Step 1: Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
from IPython.display import Image
import os
from IPython.display import display
from PIL import Image as PILImage

# %% [markdown]
# #### Step 2: Import Images

# %%
img = cv2.imread("008.jpg",cv2.IMREAD_COLOR)

# Display 18x18 pixel image.
Image(filename='008.jpg')

# %% [markdown]
# #### Step 3: Convert to Black and White

# %%
# Convert the image to grayscale
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Apply a binary threshold to create a black and white image
_, img = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY)

# %%
# Replace the color image with the black and white image
cv2.imwrite("008.jpg", img)
# Out:
# True

# %%
# Display the modified image
Image(filename='006.jpg')

# %% [markdown]
# #### Step 4: Image Griding

# %%
img = cv2.imread("008.jpg",cv2.IMREAD_COLOR)

# %%
# Convert the image to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Determine the grid size (in this case, 3x3 grids)
grid_size = 3

# Convert the image to a NumPy array for easier manipulation
img_array = np.array(img)

# Calculate the dimensions of each grid
grid_height = img_gray.shape[0] // grid_size
grid_width = img_gray.shape[1] // grid_size

# %%
# Create an empty list to store the individual grid images
grid_images = []

# Iterate over rows and columns to extract each grid
for i in range(grid_size):
    for j in range(grid_size):
        y_start = i * grid_height
        y_end = (i + 1) * grid_height
        x_start = j * grid_width
        x_end = (j + 1) * grid_width
        grid = img_array[y_start:y_end, x_start:x_end]
        grid_images.append(grid)

# %%
# Display the individual grid images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(6, 6))
for i, ax in enumerate(axes.flat):
    ax.imshow(grid_images[i], cmap='gray')
    ax.axis('off')

plt.show()

# %% [markdown]
# #### Step 4: Fearure Extraction

# %%
# Iterate over rows and columns to extract each grid
for i in range(grid_size):
    for j in range(grid_size):
        y_start = i * grid_height
        y_end = (i + 1) * grid_height
        x_start = j * grid_width
        x_end = (j + 1) * grid_width
        grid = img_gray[y_start:y_end, x_start:x_end]

        if np.any(grid < 255) and np.any(grid > 0):
            # Save the individual grid image if it contains black and white pixels
            grid_filename = f"grid_{i}_{j}.jpg"
            cv2.imwrite(grid_filename, grid)
            print(f"Saved grid image: {grid_filename}")
            # Display 18x18 pixel image.
            Image(filename= f"grid_{i}_{j}.jpg")
# Out:
# Saved grid image: grid_0_1.jpg
# Saved grid image: grid_1_1.jpg
# Saved grid image: grid_2_2.jpg

# %%
Image(filename= f"grid_0_1.jpg")

# %%
Image(filename= f"grid_1_1.jpg")

# %%
Image(filename= f"grid_2_2.jpg")
